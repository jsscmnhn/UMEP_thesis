# %%
import pandas as pd

df = pd.read_csv("D:/40523.txt", sep="\t", encoding='latin1')

# Check the available columns
print(df.columns)

# Filter by TraitName to find canopy radius or height
print(df['TraitName'].unique())
print(df)
# Out:
# Index(['LastName', 'FirstName', 'DatasetID', 'Dataset', 'SpeciesName',
#        'AccSpeciesID', 'AccSpeciesName', 'ObservationID', 'ObsDataID',
#        'TraitID', 'TraitName', 'DataID', 'DataName', 'OriglName',
#        'OrigValueStr', 'OrigUnitStr', 'ValueKindName', 'OrigUncertaintyStr',
#        'UncertaintyName', 'Replicates', 'StdValue', 'UnitName',
#        'RelUncertaintyPercent', 'OrigObsDataID', 'ErrorRisk', 'Reference',
#        'Comment', 'StdValueStr', 'Unnamed: 28'],
#       dtype='object')
# ['Crown (canopy) height (base to top)'
#  'Crown (canopy) length: diameter along the longest axis' 'Plant height'
#  nan]
#      LastName FirstName  DatasetID  \
# 0      Medlyn   Belinda         12
# 1      Medlyn   Belinda         12
# 2     Falster    Daniel        431
# 3     Falster    Daniel        431
# 4     Falster    Daniel        431
# ...       ...       ...        ...
# 1313  Falster    Daniel        431
# 1314  Falster    Daniel        431
# ...
